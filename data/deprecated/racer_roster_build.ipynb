# %% [markdown]
# Considerations is BEARMAN was on multiple teams in 2024

# %%
constructors_2023 = ['RBR', 'MCL', 'MER', 'FER', 'AMR', 'ALP', 'AT', 'WIL', 'HAS', 'ALF']
constructors_2024 = ['RBR', 'MCL', 'MER', 'FER', 'AMR', 'ALP', 'RB', 'WIL', 'HAS', 'KCK']
constructors_2025 = ['RBR', 'MCL', 'MER', 'FER', 'AMR', 'ALP', 'RB', 'WIL', 'HAS', 'KCK']

years = [constructors_2023, constructors_2024, constructors_2025]

# ----------------------------
# 2023 (season-level defaults)
# ----------------------------
drivers_2023 = {
    # Red Bull
    "VER": "RBR",
    "PER": "RBR",

    # McLaren
    "NOR": "MCL",
    "PIA": "MCL",

    # Mercedes
    "HAM": "MER",
    "RUS": "MER",

    # Ferrari
    "LEC": "FER",
    "SAI": "FER",

    # Aston Martin
    "ALO": "AMR",
    "STR": "AMR",

    # Alpine
    "OCO": "ALP",
    "GAS": "ALP",

    # AlphaTauri
    "TSU": "AT",
    "DEV": "AT",
    "RIC": "AT",
    "LAW": "AT",

    # Williams
    "ALB": "WIL",
    "SAR": "WIL",

    # Haas
    "MAG": "HAS",
    "HUL": "HAS",

    # Alfa Romeo
    "BOT": "ALF",
    "ZHO": "ALF",
}


# ----------------------------
# 2024 (season-level defaults)
# ----------------------------
drivers_2024 = {
    # Red Bull
    "VER": "RBR",
    "PER": "RBR",

    # McLaren
    "NOR": "MCL",
    "PIA": "MCL",

    # Mercedes
    "HAM": "MER",
    "RUS": "MER",

    # Ferrari
    "LEC": "FER",
    "SAI": "FER",
    "BEA": "FER",   # one-off in 2024 (still map to team)

    # Aston Martin
    "ALO": "AMR",
    "STR": "AMR",

    # Alpine
    "OCO": "ALP",
    "GAS": "ALP",

    # RB (Visa Cash App RB)
    "TSU": "RB",
    "RIC": "RB",
    "LAW": "RB",

    # Williams
    "ALB": "WIL",
    "SAR": "WIL",
    "COL": "WIL",

    # Haas
    "MAG": "HAS",
    "HUL": "HAS",
    "BEA": "HAS",   # Bearman also appears for Haas in 2024 in your notes

    # Stake/Sauber
    "BOT": "KCK",
    "ZHO": "KCK",
}

# So you MUST NOT rely on season-level dict for BEA in 2024 as he appears for multiple teams.


# ----------------------------
# 2025 (season-level defaults)
# ----------------------------
drivers_2025 = {
    # Red Bull
    "VER": "RBR",
    "PER": "RBR",

    # McLaren
    "NOR": "MCL",
    "PIA": "MCL",

    # Mercedes
    "RUS": "MER",
    "ANT": "MER",

    # Ferrari
    "LEC": "FER",
    "HAM": "FER",

    # Aston Martin
    "ALO": "AMR",
    "STR": "AMR",

    # Alpine
    "GAS": "ALP",
    "DOO": "ALP",

    # RB
    "TSU": "RB",
    "LAW": "RB",

    # Williams
    "ALB": "WIL",
    "SAI": "WIL",

    # Haas
    "BEA": "HAS",
    "OCO": "HAS",

    # Stake/Sauber 
    "HUL": "KCK",
    "BOR": "KCK"
}


# ----------------------------
# 2026 (subject to change)
# ----------------------------
drivers_2026 = {
    # Red Bull
    "VER": "RBR",
    "PER": "RBR",

    # McLaren
    "NOR": "MCL",
    "PIA": "MCL",

    # Mercedes
    "RUS": "MER",
    "ANT": "MER",

    # Ferrari
    "LEC": "FER",
    "HAM": "FER",

    # Aston Martin
    "ALO": "AMR",
    "STR": "AMR",

    # Alpine
    "GAS": "ALP",
    "DOO": "ALP",

    # RB
    "TSU": "RB",
    "LAW": "RB",

    # Williams
    "ALB": "WIL",
    "SAI": "WIL",

    # Haas
    "BEA": "HAS",
    "OCO": "HAS",

    # Stake/Sauber 
    "HUL": "KCK",
    "BOR": "KCK"
}
