# %% [markdown]
# # Historical Data Import, Reconfiguration, and Clean
#
# #### This notebook covers the extraction of historical rosters and driver/contructor points and prices from 2023 through 2026
# #### Data that I have inputed (rawHistPointandPrice.xlsx) was manually pulled from `https://f1fantasytools.com/statistics`
#
#
# FUTURE NOTE:
#
# Need to be able to ingest 2026 data eventually

# %% [markdown]
# ### Libraries

# %%
import os
from pathlib import Path
import requests
import pandas as pd
import importlib



#Loading the Placement Table Module
import sys
sys.path.append("/Users/jackguptill/Library/CloudStorage/OneDrive-Personal/Code/F1FantasyProject/notebooks/cleaning")

import placementTable as pt
importlib.reload(pt)
# Out:
# Resolved file path: C:\Users\jackg\code\F1Fantasy\data\clean\race_session_meeting_info.csv
# Exists: True
# Resolved file path: C:\Users\jackg\code\F1Fantasy\data\clean\race_session_meeting_info.csv
# Exists: True
# <module 'placementTable' from 'c:\\Users\\jackg\\code\\F1Fantasy\\notebooks\\cleaning\\placementTable.py'>

# %% [markdown]
# ### Setting working directory to make it easy for file path management

# %%
working_directory = Path.cwd().parent.parent
print(working_directory)

file_path = working_directory / "data" / "raw" / "rawHistPointAndPrice.xlsx"
# Out:
# c:\Users\jackg\code\F1Fantasy

# %% [markdown]
# ### Importing Sheets

# %%
sheet_names =["2023DriverPrice", "2023ConstructorPrice", "2023DriverPoints","2023ConstructorPoints","2023DriverRoster", 
              "2024DriverPrice", "2024ConstructorPrice", "2024DriverPoints", "2024ConstructorPoints", "2024DriverRoster",
              "2025DriverPrice", "2025ConstructorPrice","2025DriverPoints", "2025ConstructorPoints",  "2025DriverRoster",
               "2026DriverRoster", "2026DriverPrice", "2026DriverPoints", "2026ConstructorPrice", "2026ConstructorPoints"]



dfs = {sheet: pd.read_excel(file_path, sheet_name=sheet) for sheet in sheet_names}

# access one
print(dfs["2023DriverPoints"].head())
# Out:
#   Unnamed: 0     1     2     3     4     5     7     8     9    10  ...    14  \
# 0        VER  35.0  61.0  36.0  37.0  64.0  35.0  46.0  35.0  56.0  ...  46.0
# 1        PER  28.0  36.0  52.0  61.0  28.0  10.0  27.0  28.0  51.0  ...  30.0
# 2        HAM  19.0  16.0  29.0  19.0  24.0  28.0  39.0  23.0  31.0  ...  29.0
# 3        NOR  -1.0   7.0  19.0   0.0   1.0   6.0  -2.0   2.0  29.0  ...  25.0
# 4        ALO  39.0  23.0  23.0  27.0  25.0  27.0  14.0  27.0  28.0  ...  62.0
#
#      15    16    17    18    19    20    21    22    23
# 0  38.0  25.0  47.0  62.0  53.0  42.0  45.0  44.0  47.0
# 1  30.0  16.0 -11.0  -3.0  32.0 -10.0  37.0  35.0  30.0
# 2  17.0  39.0  20.0   6.0  -4.0  41.0  13.0  26.0  14.0
# 3   9.0  30.0  31.0  41.0  46.0  48.0  57.0 -14.0  22.0
# 4   5.0  -1.0  16.0  25.0  -9.0 -16.0  39.0  12.0  16.0
#
# [5 rows x 23 columns]

# %% [markdown]
# For each sheet we will need to unpivot them so that they are long and not wide format
# Each sheet will need to have col headers of: YEAR, RACE, DRIVER, POINTS/PRICE

# %% [markdown]
# #### Sheet Organization

# %%
driver_price_sheets = ["2023DriverPrice", "2024DriverPrice", "2025DriverPrice", "2026DriverPrice"]
driver_points_sheets = ["2023DriverPoints", "2024DriverPoints", "2025DriverPoints", "2026DriverPoints"]

con_price_sheets = ["2023ConstructorPrice", "2024ConstructorPrice", "2025ConstructorPrice", "2026ConstructorPrice"]
con_points_sheets = ["2023ConstructorPoints", "2024ConstructorPoints", "2025ConstructorPoints", "2026ConstructorPoints"]


driver_roster_sheets = ["2023DriverRoster", "2024DriverRoster", "2025DriverRoster", "2026DriverRoster"]

# %% [markdown]
# ### Two functions to help unpivot/melt the existing pivots in each sheet.

# %%
def standardize_headers(df: pd.DataFrame, first_col_name: str) -> pd.DataFrame:
    df = df.copy()

    # Dropping unnamed cols
    unnamed_cols = [c for c in df.columns if str(c).startswith("Unnamed")]
    for c in unnamed_cols:
        if df[c].isna().all():
            df = df.drop(columns=c)

    # renaming first col to first_col_name
    df = df.rename(columns={df.columns[0]: first_col_name})

    # Clean race headers
    cleaned_cols = [first_col_name]
    for c in df.columns[1:]:
        try:
            cleaned_cols.append(int(float(str(c).strip())))
        except ValueError:
            cleaned_cols.append(str(c).strip())

    df.columns = cleaned_cols
    return df


def convert_to_long(sheets: dict, var_name: str, value_name: str, type: str):
    longs = []

    for sheet_name, df in sheets.items():
        df_clean = standardize_headers(df, first_col_name=type)

        temp = (
            df_clean
            .melt(id_vars=type, var_name=var_name, value_name=value_name)
            .assign(source_sheet=sheet_name)
        )
        longs.append(temp)

    return pd.concat(longs, ignore_index=True)

# %% [markdown]
# ### Melting each sheet to long format

# %%
driver_price_dfs  = {k: dfs[k] for k in driver_price_sheets}
driver_points_dfs = {k: dfs[k] for k in driver_points_sheets}

con_price_dfs = {k: dfs[k] for k in con_price_sheets}
con_points_dfs = {k: dfs[k] for k in con_points_sheets}

driver_roster_dfs = {k: dfs[k] for k in driver_roster_sheets}

driver_price_long  = convert_to_long(driver_price_dfs,  var_name="race", value_name="price",  type = "driver")
driver_points_long  = convert_to_long(driver_points_dfs,  var_name="race", value_name="points",  type = "driver")

con_price_long = convert_to_long(con_price_dfs, var_name="race", value_name="price", type= "constructor")
con_points_long = convert_to_long(con_points_dfs, var_name="race", value_name="points", type= "constructor")

driver_roster_long = convert_to_long(driver_roster_dfs, var_name="race", value_name="constructor", type='driver')

# %%
driver_price_long.head()
# Out:
#   driver race  price     source_sheet
# 0    VER    1   26.9  2023DriverPrice
# 1    HAM    1   23.7  2023DriverPrice
# 2    LEC    1   21.2  2023DriverPrice
# 3    PER    1   18.0  2023DriverPrice
# 4    RUS    1   18.6  2023DriverPrice

# %%
driver_points_long.head()
# Out:
#   driver race  points      source_sheet
# 0    VER    1    35.0  2023DriverPoints
# 1    PER    1    28.0  2023DriverPoints
# 2    HAM    1    19.0  2023DriverPoints
# 3    NOR    1    -1.0  2023DriverPoints
# 4    ALO    1    39.0  2023DriverPoints

# %%
con_price_long.head()
# Out:
#   constructor race  price          source_sheet
# 0         RED    1   27.2  2023ConstructorPrice
# 1         MER    1   25.1  2023ConstructorPrice
# 2         FER    1   22.1  2023ConstructorPrice
# 3         MCL    1    9.1  2023ConstructorPrice
# 4         ALP    1   10.1  2023ConstructorPrice

# %%
con_points_long.head()
# Out:
#   constructor race  points           source_sheet
# 0         RED    1    78.0  2023ConstructorPoints
# 1         MER    1    45.0  2023ConstructorPoints
# 2         FER    1    31.0  2023ConstructorPoints
# 3         MCL    1   -16.0  2023ConstructorPoints
# 4         AST    1    56.0  2023ConstructorPoints

# %%
driver_roster_long.head()
# Out:
#   driver race constructor      source_sheet
# 0    VER    1         RBR  2023DriverRoster
# 1    PER    1         RBR  2023DriverRoster
# 2    NOR    1         MCL  2023DriverRoster
# 3    PIA    1         MCL  2023DriverRoster
# 4    HAM    1         MER  2023DriverRoster

# %%
missing_constructors = driver_roster_long[driver_roster_long["constructor"].isna()]
missing_constructors['driver'].unique()

driver_roster_long = driver_roster_long.dropna(subset=["constructor"])

# %% [markdown]
# ### Slight Feature Engineering and Conversions

# %%
dfs = [driver_price_long, driver_points_long, con_price_long, con_points_long, driver_roster_long]

# %%
#Extracting out year from source_sheet column string
for df in dfs:
    df["year"] = df["source_sheet"].str[:4].astype(int)
    df = df.drop(columns="source_sheet", inplace=True)

# %%
for df in dfs:
    df["race"] = df["race"].astype("int")


    print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1724 entries, 0 to 1723
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   driver  1724 non-null   object
#  1   race    1724 non-null   int64
#  2   price   1487 non-null   float64
#  3   year    1724 non-null   int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 54.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1676 entries, 0 to 1675
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   driver  1676 non-null   object
#  1   race    1676 non-null   int64
#  2   points  1465 non-null   float64
#  3   year    1676 non-null   int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 52.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   constructor  744 non-null    object
#  1   race         744 non-null    int64
#  2   price        744 non-null    float64
#  3   year         744 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 23.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   constructor  768 non-null    object
#  1   race         768 non-null    int64
#  2   points       757 non-null    float64
#  3   year         768 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 24.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 1488 entries, 0 to 1627
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   driver       1488 non-null   object
#  1   race         1488 non-null   int64
#  2   constructor  1488 non-null   object
#  3   year         1488 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 58.1+ KB
# None

# %% [markdown]
# ### Creating a Race Dimension Table using the Open F1 API
#
# - We have created two functions that allow us to create df's of output from the API at both the meeting and the race session level
# - The last function then merges both tables together to create the dimension table. this will be useful when joining to other tables for race session info
#
#
# - I absolutely am loving how easy it is to work with this API
#
#
# This API will only work on historical races, and wont be able to input of current week races

# %%
def build_meetings_openf1(year: int):
    url = f"https://api.openf1.org/v1/meetings?year={year}"
    meetings = requests.get(url, timeout=30).json()
    df = pd.DataFrame(meetings)

    # Sort by start date and create race number 1..N
    df = df.sort_values("date_start").reset_index(drop=True)
    df["race"] = df.index + 1

    # Extracting Columns
    meetings = df.rename(columns={
        "meeting_name": "race_name",
        "date_start": "weekend_start_date",
        "country_name": "country",
    })[["year", "race", "meeting_key", "race_name", "weekend_start_date", "location", "country_code"]]

    return meetings

def build_sessions_openf1(year:int):
    """
    This will pull each race session

    Ideally we will pull date_start, date_end, and country_code
    """

    url = f"https://api.openf1.org/v1/sessions?year={year}&session_name=Race"
    sessions = requests.get(url, timeout=30).json()
    df = pd.DataFrame(sessions)

    if df.empty:
        return pd.DataFrame(columns=["meeting_key", "race_start_date", "race_end_date"])

    # Keep only what is needed
    sessions = df.rename(columns={
        "date_start": "race_start_date",
        "date_end": "race_end_date",
    })[["meeting_key", "race_start_date", "race_end_date"]].drop_duplicates()

    return sessions


def build_race_dim_open_f1(year:int):
    meetings = build_meetings_openf1(year)
    race_sessions = build_sessions_openf1(year)

    #join
    out = meetings.merge(race_sessions, on="meeting_key", how="left")
    out = out.rename(columns={"race_start_date": "start_date"})

    return out[["year", "race", "race_name", "start_date", "location", "country_code", "meeting_key"]]

# %%
race_dim = pd.concat([build_race_dim_open_f1(y) for y in [2023, 2024, 2025, 2026]], ignore_index=True)

# %%
#race_dim.head()
race_dim.tail(100)
#race_dim.info()
# Out:
#     year  race                 race_name                 start_date  \
# 0   2023     1        Pre-Season Testing                        NaN
# 1   2023     2        Bahrain Grand Prix  2023-03-05T15:00:00+00:00
# 2   2023     3  Saudi Arabian Grand Prix  2023-03-19T17:00:00+00:00
# 3   2023     4     Australian Grand Prix  2023-04-02T05:00:00+00:00
# 4   2023     5     Azerbaijan Grand Prix  2023-04-30T11:00:00+00:00
# ..   ...   ...                       ...                        ...
# 95  2026    22    Mexico City Grand Prix  2026-11-01T20:00:00+00:00
# 96  2026    23      São Paulo Grand Prix  2026-11-08T17:00:00+00:00
# 97  2026    24      Las Vegas Grand Prix  2026-11-22T04:00:00+00:00
# 98  2026    25          Qatar Grand Prix  2026-11-29T16:00:00+00:00
# 99  2026    26      Abu Dhabi Grand Prix  2026-12-06T13:00:00+00:00
#
#        location country_code  meeting_key
# 0        Sakhir          BRN         1140
# 1        Sakhir          BRN         1141
# 2        Jeddah          KSA         1142
# 3     Melbourne          AUS         1143
# 4          Baku          AZE         1207
# ..          ...          ...          ...
# 95  Mexico City          MEX         1298
# 96    São Paulo          BRA         1299
# 97    Las Vegas          USA         1300
# 98       Lusail          QAT         1301
# 99   Yas Marina          UAE         1302
#
# [100 rows x 7 columns]

# %% [markdown]
# ### Need to fix race_num
# - dont want to include pre-season testing
# - sort by start date and have the min date be 1
# - increment race_num until near year is reached

# %%
race_dim = race_dim[~race_dim["race_name"].str.contains("test", case=False, na=False)].copy()
race_dim["start_date"] = pd.to_datetime(race_dim["start_date"], utc=True, errors="coerce")
race_dim = race_dim.sort_values(["year", "start_date", "race_name"]).reset_index(drop=True)
race_dim["race"] = race_dim.groupby("year").cumcount() + 1 #renumbering

# %%
race_dim.tail(50)
# Out:
#     year  race                  race_name                start_date  \
# 45  2024    23           Qatar Grand Prix 2024-12-01 16:00:00+00:00
# 46  2024    24       Abu Dhabi Grand Prix 2024-12-08 13:00:00+00:00
# 47  2025     1      Australian Grand Prix 2025-03-16 04:00:00+00:00
# 48  2025     2         Chinese Grand Prix 2025-03-23 07:00:00+00:00
# 49  2025     3        Japanese Grand Prix 2025-04-06 05:00:00+00:00
# 50  2025     4         Bahrain Grand Prix 2025-04-13 15:00:00+00:00
# 51  2025     5   Saudi Arabian Grand Prix 2025-04-20 17:00:00+00:00
# 52  2025     6           Miami Grand Prix 2025-05-04 20:00:00+00:00
# 53  2025     7  Emilia Romagna Grand Prix 2025-05-18 13:00:00+00:00
# 54  2025     8          Monaco Grand Prix 2025-05-25 13:00:00+00:00
# 55  2025     9         Spanish Grand Prix 2025-06-01 13:00:00+00:00
# 56  2025    10        Canadian Grand Prix 2025-06-15 18:00:00+00:00
# 57  2025    11        Austrian Grand Prix 2025-06-29 13:00:00+00:00
# 58  2025    12         British Grand Prix 2025-07-06 14:00:00+00:00
# 59  2025    13         Belgian Grand Prix 2025-07-27 13:00:00+00:00
# 60  2025    14       Hungarian Grand Prix 2025-08-03 13:00:00+00:00
# 61  2025    15           Dutch Grand Prix 2025-08-31 13:00:00+00:00
# 62  2025    16         Italian Grand Prix 2025-09-07 13:00:00+00:00
# 63  2025    17      Azerbaijan Grand Prix 2025-09-21 11:00:00+00:00
# 64  2025    18       Singapore Grand Prix 2025-10-05 12:00:00+00:00
# 65  2025    19   United States Grand Prix 2025-10-19 19:00:00+00:00
# 66  2025    20     Mexico City Grand Prix 2025-10-26 20:00:00+00:00
# 67  2025    21       São Paulo Grand Prix 2025-11-09 17:00:00+00:00
# 68  2025    22       Las Vegas Grand Prix 2025-11-23 04:00:00+00:00
# 69  2025    23           Qatar Grand Prix 2025-11-30 16:00:00+00:00
# 70  2025    24       Abu Dhabi Grand Prix 2025-12-07 13:00:00+00:00
# 71  2026     1      Australian Grand Prix 2026-03-08 04:00:00+00:00
# 72  2026     2         Chinese Grand Prix 2026-03-15 07:00:00+00:00
# 73  2026     3        Japanese Grand Prix 2026-03-29 05:00:00+00:00
# 74  2026     4         Bahrain Grand Prix 2026-04-12 15:00:00+00:00
# 75  2026     5   Saudi Arabian Grand Prix 2026-04-19 17:00:00+00:00
# 76  2026     6           Miami Grand Prix 2026-05-03 20:00:00+00:00
# 77  2026     7        Canadian Grand Prix 2026-05-24 20:00:00+00:00
# 78  2026     8          Monaco Grand Prix 2026-06-07 13:00:00+00:00
# 79  2026     9       Barcelona Grand Prix 2026-06-14 13:00:00+00:00
# 80  2026    10        Austrian Grand Prix 2026-06-28 13:00:00+00:00
# 81  2026    11         British Grand Prix 2026-07-05 14:00:00+00:00
# 82  2026    12         Belgian Grand Prix 2026-07-19 13:00:00+00:00
# 83  2026    13       Hungarian Grand Prix 2026-07-26 13:00:00+00:00
# 84  2026    14           Dutch Grand Prix 2026-08-23 13:00:00+00:00
# 85  2026    15         Italian Grand Prix 2026-09-06 13:00:00+00:00
# 86  2026    16         Spanish Grand Prix 2026-09-13 13:00:00+00:00
# 87  2026    17      Azerbaijan Grand Prix 2026-09-26 11:00:00+00:00
# 88  2026    18       Singapore Grand Prix 2026-10-11 12:00:00+00:00
# 89  2026    19   United States Grand Prix 2026-10-25 20:00:00+00:00
# 90  2026    20     Mexico City Grand Prix 2026-11-01 20:00:00+00:00
# 91  2026    21       São Paulo Grand Prix 2026-11-08 17:00:00+00:00
# 92  2026    22       Las Vegas Grand Prix 2026-11-22 04:00:00+00:00
# 93  2026    23           Qatar Grand Prix 2026-11-29 16:00:00+00:00
# 94  2026    24       Abu Dhabi Grand Prix 2026-12-06 13:00:00+00:00
#
#              location country_code  meeting_key
# 45             Lusail          QAT         1251
# 46         Yas Island          UAE         1252
# 47          Melbourne          AUS         1254
# 48           Shanghai          CHN         1255
# 49             Suzuka          JPN         1256
# 50             Sakhir          BRN         1257
# 51             Jeddah          KSA         1258
# 52      Miami Gardens          USA         1259
# 53              Imola          ITA         1260
# 54             Monaco          MON         1261
# 55          Barcelona          ESP         1262
# 56           Montréal          CAN         1263
# 57          Spielberg          AUT         1264
# 58        Silverstone          GBR         1277
# 59  Spa-Francorchamps          BEL         1265
# 60           Budapest          HUN         1266
# 61          Zandvoort          NED         1267
# 62              Monza          ITA         1268
# 63               Baku          AZE         1269
# 64         Marina Bay          SGP         1270
# 65             Austin          USA         1271
# 66        Mexico City          MEX         1272
# 67          São Paulo          BRA         1273
# 68          Las Vegas          USA         1274
# 69             Lusail          QAT         1275
# 70         Yas Island          UAE         1276
# 71          Melbourne          AUS         1279
# 72           Shanghai          CHN         1280
# 73             Suzuka          JPN         1281
# 74             Sakhir          BRN         1282
# 75             Jeddah          KSA         1283
# 76      Miami Gardens          USA         1284
# 77           Montréal          CAN         1285
# 78        Monte Carlo          MON         1286
# 79          Barcelona          ESP         1287
# 80          Spielberg          AUT         1288
# 81        Silverstone          GBR         1289
# 82  Spa-Francorchamps          BEL         1290
# 83           Budapest          HUN         1291
# 84          Zandvoort          NED         1292
# 85              Monza          ITA         1293
# 86             Madrid          ESP         1294
# 87               Baku          AZE         1295
# 88         Marina Bay          SGP         1296
# 89             Austin          USA         1297
# 90        Mexico City          MEX         1298
# 91          São Paulo          BRA         1299
# 92          Las Vegas          USA         1300
# 93             Lusail          QAT         1301
# 94         Yas Marina          UAE         1302

# %% [markdown]
# ### Taking care of Missingness

# %%
race_dim[race_dim["start_date"].isna()]
# Out:
# Empty DataFrame
# Columns: [year, race, race_name, start_date, location, country_code, meeting_key]
# Index: []

# %%
#dropping all of these as we are not conserned about modeling pre-season testing as we cant see the data from those sessions anyway
# even if we could see that data it is well known that constructors sand bag their performance

# %%
race_dim = race_dim.dropna(subset=["start_date"])
race_dim["start_date"].isna().sum()
# Out:
# np.int64(0)

# %%
race_dim.tail()
# Out:
#     year  race               race_name                start_date     location  \
# 90  2026    20  Mexico City Grand Prix 2026-11-01 20:00:00+00:00  Mexico City
# 91  2026    21    São Paulo Grand Prix 2026-11-08 17:00:00+00:00    São Paulo
# 92  2026    22    Las Vegas Grand Prix 2026-11-22 04:00:00+00:00    Las Vegas
# 93  2026    23        Qatar Grand Prix 2026-11-29 16:00:00+00:00       Lusail
# 94  2026    24    Abu Dhabi Grand Prix 2026-12-06 13:00:00+00:00   Yas Marina
#
#    country_code  meeting_key
# 90          MEX         1298
# 91          BRA         1299
# 92          USA         1300
# 93          QAT         1301
# 94          UAE         1302

# %%
race_dim["start_date"] = pd.to_datetime(race_dim["start_date"], utc=True)
race_dim["month"] = race_dim["start_date"].dt.month
race_dim["start_epoch"] = race_dim["start_date"].astype("int64") // 10**9

# %%
race_dim.head()
# Out:
#    year  race                 race_name                start_date   location  \
# 0  2023     1        Bahrain Grand Prix 2023-03-05 15:00:00+00:00     Sakhir
# 1  2023     2  Saudi Arabian Grand Prix 2023-03-19 17:00:00+00:00     Jeddah
# 2  2023     3     Australian Grand Prix 2023-04-02 05:00:00+00:00  Melbourne
# 3  2023     4     Azerbaijan Grand Prix 2023-04-30 11:00:00+00:00       Baku
# 4  2023     5          Miami Grand Prix 2023-05-07 19:30:00+00:00      Miami
#
#   country_code  meeting_key  month  start_epoch
# 0          BRN         1141      3   1678028400
# 1          KSA         1142      3   1679245200
# 2          AUS         1143      4   1680411600
# 3          AZE         1207      4   1682852400
# 4          USA         1208      5   1683487800

# %%
race_dim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          95 non-null     int64
#  1   race          95 non-null     int64
#  2   race_name     95 non-null     object
#  3   start_date    95 non-null     datetime64[ns, UTC]
#  4   location      95 non-null     object
#  5   country_code  95 non-null     object
#  6   meeting_key   95 non-null     int64
#  7   month         95 non-null     int32
#  8   start_epoch   95 non-null     int64
# dtypes: datetime64[ns, UTC](1), int32(1), int64(4), object(3)
# memory usage: 6.4+ KB

# %% [markdown]
# ### Exporting the dimension table on its own if needed later for anything

# %%
file_path = working_directory / "data" / "clean" / "race_session_meeting_info.csv"
race_dim.to_csv(file_path)

# %% [markdown]
# ### Creating the Placement Table
# - will use the race_session_meeting_info table for the meeting keys

# %%
placement_table = pt.get_placement_df()
# Out:
# ADDED session_key 7953
# ADDED session_key 7779
# ADDED session_key 7787
# ADDED session_key 9070
# ADDED session_key 9078
# SKIPPING session_key 9086: 404 not found for session_key:9086
# ADDED session_key 9094
# ADDED session_key 9102
# ADDED session_key 9110
# ADDED session_key 9118
# ADDED session_key 9126
# Rate Limited on session_key=9133. Sleeping 2 seconds
# Rate Limited on session_key=9133. Sleeping 4 seconds
# Rate Limited on session_key=9133. Sleeping 6 seconds
# Rate Limited on session_key=9133. Sleeping 8 seconds
# Rate Limited on session_key=9133. Sleeping 10 seconds
# Rate Limited on session_key=9133. Sleeping 12 seconds
# ADDED session_key 9133
# ADDED session_key 9141
# ADDED session_key 9149
# ADDED session_key 9157
# ADDED session_key 9165
# ADDED session_key 9173
# ADDED session_key 9221
# ADDED session_key 9213
# ADDED session_key 9181
# ADDED session_key 9205
# ADDED session_key 9189
# ADDED session_key 9197
# ADDED session_key 9472
# ADDED session_key 9480
# Rate Limited on session_key=9488. Sleeping 2 seconds
# Rate Limited on session_key=9488. Sleeping 4 seconds
# Rate Limited on session_key=9488. Sleeping 6 seconds
# Rate Limited on session_key=9488. Sleeping 8 seconds
# Rate Limited on session_key=9488. Sleeping 10 seconds
# Rate Limited on session_key=9488. Sleeping 12 seconds
# ADDED session_key 9488
# ADDED session_key 9496
# ADDED session_key 9673
# ADDED session_key 9507
# ADDED session_key 9515
# ADDED session_key 9523
# ADDED session_key 9531
# ADDED session_key 9539
# ADDED session_key 9550
# ADDED session_key 9558
# ADDED session_key 9566
# ADDED session_key 9574
# ADDED session_key 9582
# ADDED session_key 9590
# ADDED session_key 9598
# Rate Limited on session_key=9606. Sleeping 2 seconds
# Rate Limited on session_key=9606. Sleeping 4 seconds
# Rate Limited on session_key=9606. Sleeping 6 seconds
# Rate Limited on session_key=9606. Sleeping 8 seconds
# Rate Limited on session_key=9606. Sleeping 10 seconds
# Rate Limited on session_key=9606. Sleeping 12 seconds
# ADDED session_key 9606
# ADDED session_key 9617
# ADDED session_key 9625
# ADDED session_key 9636
# ADDED session_key 9644
# ADDED session_key 9655
# ADDED session_key 9662
# ADDED session_key 9693
# ADDED session_key 9998
# ADDED session_key 10006
# ADDED session_key 10014
# ADDED session_key 10022
# ADDED session_key 10033
# ADDED session_key 9987
# ADDED session_key 9979
# Rate Limited on session_key=9971. Sleeping 2 seconds
# Rate Limited on session_key=9971. Sleeping 4 seconds
# Rate Limited on session_key=9971. Sleeping 6 seconds
# Rate Limited on session_key=9971. Sleeping 8 seconds
# Rate Limited on session_key=9971. Sleeping 10 seconds
# ADDED session_key 9971
# ADDED session_key 9963
# ADDED session_key 9955
# ADDED session_key 9947
# ADDED session_key 9939
# ADDED session_key 9928
# ADDED session_key 9920
# ADDED session_key 9912
# ADDED session_key 9904
# ADDED session_key 9896
# ADDED session_key 9888
# ADDED session_key 9877
# ADDED session_key 9869
# ADDED session_key 9858
# ADDED session_key 9850
# Rate Limited on session_key=9839. Sleeping 2 seconds
# Rate Limited on session_key=9839. Sleeping 4 seconds
# Rate Limited on session_key=9839. Sleeping 6 seconds
# Rate Limited on session_key=9839. Sleeping 8 seconds
# Rate Limited on session_key=9839. Sleeping 10 seconds
# Rate Limited on session_key=9839. Sleeping 12 seconds
# ADDED session_key 9839
# ADDED session_key 11234
# ADDED session_key 11245
# ADDED session_key 11253
# SKIPPING session_key 11261: 404 not found for session_key:11261
# SKIPPING session_key 11269: 404 not found for session_key:11269
# SKIPPING session_key 11280: 404 not found for session_key:11280
# SKIPPING session_key 11291: 404 not found for session_key:11291
# SKIPPING session_key 11299: 404 not found for session_key:11299
# SKIPPING session_key 11307: 404 not found for session_key:11307
# SKIPPING session_key 11315: 404 not found for session_key:11315
# SKIPPING session_key 11326: 404 not found for session_key:11326
# SKIPPING session_key 11334: 404 not found for session_key:11334
# SKIPPING session_key 11342: 404 not found for session_key:11342
# SKIPPING session_key 11353: 404 not found for session_key:11353
# SKIPPING session_key 11361: 404 not found for session_key:11361
# SKIPPING session_key 11369: 404 not found for session_key:11369
# SKIPPING session_key 11377: 404 not found for session_key:11377
# SKIPPING session_key 11388: 404 not found for session_key:11388
# SKIPPING session_key 11396: 404 not found for session_key:11396
# SKIPPING session_key 11404: 404 not found for session_key:11404
# SKIPPING session_key 11412: 404 not found for session_key:11412
# SKIPPING session_key 11420: 404 not found for session_key:11420
# SKIPPING session_key 11428: 404 not found for session_key:11428
# SKIPPING session_key 11436: 404 not found for session_key:11436

# %%
placement_table.shape
# Out:
# (1463, 12)

# %%
placement_table.tail()
# Out:
#                     date_start driver  driver_number  position  points  \
# 1458 2026-03-29 05:00:00+00:00    ALO             14      18.0     0.0
# 1459 2026-03-29 05:00:00+00:00    BOT             77      19.0     0.0
# 1460 2026-03-29 05:00:00+00:00    ALB             23      20.0     0.0
# 1461 2026-03-29 05:00:00+00:00    STR             18       NaN     0.0
# 1462 2026-03-29 05:00:00+00:00    BEA             87       NaN     0.0
#
#      gap_to_leader  meeting_key  session_key    dnf    dns    dsq  nc
# 1458        +1 LAP         1281        11253  False  False  False   0
# 1459        +1 LAP         1281        11253  False  False  False   0
# 1460       +2 LAPS         1281        11253  False  False  False   0
# 1461          None         1281        11253   True  False  False   0
# 1462          None         1281        11253   True  False  False   0

# %% [markdown]
# ##### Saving the placement_table

# %%
pt_path = working_directory / "data" / "clean" / "placement_table.csv"
placement_table.to_csv(pt_path)

# %% [markdown]
# ### Merging the basic Race Dimension table via OpenF1 to each existing df

# %%
#merging the basic race_dim to each df
for i in range(0, len(dfs)): 
    dfs[i] = dfs[i].merge(race_dim, how="left", on=["race", "year"])

# %%
dfs[4].tail()
# Out:
#      driver  race constructor  year         race_name  \
# 1483    BOR     6         AUD  2026  Miami Grand Prix
# 1484    LIN     6          RB  2026  Miami Grand Prix
# 1485    COL     6         ALP  2026  Miami Grand Prix
# 1486    PER     6         CAD  2026  Miami Grand Prix
# 1487    BOT     6         CAD  2026  Miami Grand Prix
#
#                     start_date       location country_code  meeting_key  \
# 1483 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284
# 1484 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284
# 1485 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284
# 1486 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284
# 1487 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284
#
#       month  start_epoch
# 1483      5   1777838400
# 1484      5   1777838400
# 1485      5   1777838400
# 1486      5   1777838400
# 1487      5   1777838400

# %%
for df in dfs:
    print(df.head())
# Out:
#   driver  race  price  year           race_name                start_date  \
# 0    VER     1   26.9  2023  Bahrain Grand Prix 2023-03-05 15:00:00+00:00
# 1    HAM     1   23.7  2023  Bahrain Grand Prix 2023-03-05 15:00:00+00:00
# 2    LEC     1   21.2  2023  Bahrain Grand Prix 2023-03-05 15:00:00+00:00
# 3    PER     1   18.0  2023  Bahrain Grand Prix 2023-03-05 15:00:00+00:00
# 4    RUS     1   18.6  2023  Bahrain Grand Prix 2023-03-05 15:00:00+00:00
#
#   location country_code  meeting_key  month  start_epoch
# 0   Sakhir          BRN         1141      3   1678028400
# 1   Sakhir          BRN         1141      3   1678028400
# 2   Sakhir          BRN         1141      3   1678028400
# 3   Sakhir          BRN         1141      3   1678028400
# 4   Sakhir          BRN         1141      3   1678028400
#   driver  race  points  year           race_name                start_date  \
# 0    VER     1    35.0  2023  Bahrain Grand Prix 2023-03-05 15:00:00+00:00
# 1    PER     1    28.0  2023  Bahrain Grand Prix 2023-03-05 15:00:00+00:00
# 2    HAM     1    19.0  2023  Bahrain Grand Prix 2023-03-05 15:00:00+00:00
# 3    NOR     1    -1.0  2023  Bahrain Grand Prix 2023-03-05 15:00:00+00:00
# 4    ALO     1    39.0  2023  Bahrain Grand Prix 2023-03-05 15:00:00+00:00
#
#   location country_code  meeting_key  month  start_epoch
# 0   Sakhir          BRN         1141      3   1678028400
# 1   Sakhir          BRN         1141      3   1678028400
# 2   Sakhir          BRN         1141      3   1678028400
# 3   Sakhir          BRN         1141      3   1678028400
# 4   Sakhir          BRN         1141      3   1678028400
#   constructor  race  price  year           race_name  \
# 0         RED     1   27.2  2023  Bahrain Grand Prix
# 1         MER     1   25.1  2023  Bahrain Grand Prix
# 2         FER     1   22.1  2023  Bahrain Grand Prix
# 3         MCL     1    9.1  2023  Bahrain Grand Prix
# 4         ALP     1   10.1  2023  Bahrain Grand Prix
#
#                  start_date location country_code  meeting_key  month  \
# 0 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 1 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 2 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 3 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 4 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
#
#    start_epoch
# 0   1678028400
# 1   1678028400
# 2   1678028400
# 3   1678028400
# 4   1678028400
#   constructor  race  points  year           race_name  \
# 0         RED     1    78.0  2023  Bahrain Grand Prix
# 1         MER     1    45.0  2023  Bahrain Grand Prix
# 2         FER     1    31.0  2023  Bahrain Grand Prix
# 3         MCL     1   -16.0  2023  Bahrain Grand Prix
# 4         AST     1    56.0  2023  Bahrain Grand Prix
#
#                  start_date location country_code  meeting_key  month  \
# 0 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 1 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 2 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 3 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 4 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
#
#    start_epoch
# 0   1678028400
# 1   1678028400
# 2   1678028400
# 3   1678028400
# 4   1678028400
#   driver  race constructor  year           race_name  \
# 0    VER     1         RBR  2023  Bahrain Grand Prix
# 1    PER     1         RBR  2023  Bahrain Grand Prix
# 2    NOR     1         MCL  2023  Bahrain Grand Prix
# 3    PIA     1         MCL  2023  Bahrain Grand Prix
# 4    HAM     1         MER  2023  Bahrain Grand Prix
#
#                  start_date location country_code  meeting_key  month  \
# 0 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 1 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 2 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 3 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
# 4 2023-03-05 15:00:00+00:00   Sakhir          BRN         1141      3
#
#    start_epoch
# 0   1678028400
# 1   1678028400
# 2   1678028400
# 3   1678028400
# 4   1678028400

# %% [markdown]
# ### Dealing with Current Week
#
# - the race_dim from the API has no data on current week, will have to rel

# %% [markdown]
# ### Checking Nulls/NA's within the Roster
# - these are racers who raaced in a given year but did not drive for the given race

# %%
driver_roster_long[driver_roster_long['constructor'].isna()]
# Out:
# Empty DataFrame
# Columns: [driver, race, constructor, year]
# Index: []

# %%
driver_roster_long.isna().sum()
# Out:
# driver         0
# race           0
# constructor    0
# year           0
# dtype: int64

# %%
driver_roster_long = driver_roster_long.dropna(subset=["constructor"]) #this will drop records where the driver didnt actually race
driver_roster_long = driver_roster_long[driver_roster_long["constructor"] != ""]
driver_roster_long.isna().sum()
dfs[4] = driver_roster_long #saving back into the list

# %% [markdown]
# ### Saving each file created seperately for later use

# %% [markdown]
# #### Team Config

# %%
raw_file_path = working_directory / "data" / "raw" / "rawHistPointAndPrice.xlsx"

#read in from excel
team_config = pd.read_excel(raw_file_path, sheet_name = "2026TeamConfig")
#save as its own csv
file_path_team_config = working_directory / "data" / "myTeam" / "teamConfig.csv"
team_config.to_csv(file_path_team_config)

# %% [markdown]
# #### Driver and Constructor Points and Prices

# %%
output_paths = ["driver_price", "driver_points", "constructor_price", "constructor_points", "driver_roster"]

for i in range(0, len(dfs)):
    file_path = working_directory / "data" / "clean" / f"{output_paths[i]}.csv"
    dfs[i].to_csv(file_path)

# %% [markdown]
# #### Verifying current week is within each df

# %%
for i in range(0, len(dfs)):
    print(dfs[i].tail(5))
# Out:
#      driver  race  price  year         race_name                start_date  \
# 1719    BOR     6    5.8  2026  Miami Grand Prix 2026-05-03 20:00:00+00:00
# 1720    LIN     6    7.6  2026  Miami Grand Prix 2026-05-03 20:00:00+00:00
# 1721    COL     6    7.6  2026  Miami Grand Prix 2026-05-03 20:00:00+00:00
# 1722    PER     6    7.0  2026  Miami Grand Prix 2026-05-03 20:00:00+00:00
# 1723    BOT     6    4.1  2026  Miami Grand Prix 2026-05-03 20:00:00+00:00
#
#            location country_code  meeting_key  month  start_epoch
# 1719  Miami Gardens          USA         1284      5   1777838400
# 1720  Miami Gardens          USA         1284      5   1777838400
# 1721  Miami Gardens          USA         1284      5   1777838400
# 1722  Miami Gardens          USA         1284      5   1777838400
# 1723  Miami Gardens          USA         1284      5   1777838400
#      driver  race  points  year         race_name                start_date  \
# 1671    BOR     6     NaN  2026  Miami Grand Prix 2026-05-03 20:00:00+00:00
# 1672    LIN     6     NaN  2026  Miami Grand Prix 2026-05-03 20:00:00+00:00
# 1673    COL     6     NaN  2026  Miami Grand Prix 2026-05-03 20:00:00+00:00
# 1674    PER     6     NaN  2026  Miami Grand Prix 2026-05-03 20:00:00+00:00
# 1675    BOT     6     NaN  2026  Miami Grand Prix 2026-05-03 20:00:00+00:00
#
#            location country_code  meeting_key  month  start_epoch
# 1671  Miami Gardens          USA         1284      5   1777838400
# 1672  Miami Gardens          USA         1284      5   1777838400
# 1673  Miami Gardens          USA         1284      5   1777838400
# 1674  Miami Gardens          USA         1284      5   1777838400
# 1675  Miami Gardens          USA         1284      5   1777838400
#     constructor  race  price  year         race_name  \
# 739         AMR     6    8.5  2026  Miami Grand Prix
# 740         HAS     6    9.2  2026  Miami Grand Prix
# 741         AUD     6    5.6  2026  Miami Grand Prix
# 742          RB     6    8.1  2026  Miami Grand Prix
# 743         CAD     6    5.0  2026  Miami Grand Prix
#
#                    start_date       location country_code  meeting_key  month  \
# 739 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284      5
# 740 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284      5
# 741 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284      5
# 742 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284      5
# 743 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284      5
#
#      start_epoch
# 739   1777838400
# 740   1777838400
# 741   1777838400
# 742   1777838400
# 743   1777838400
#     constructor  race  points  year         race_name  \
# 763         AMR     6     NaN  2026  Miami Grand Prix
# 764         HAS     6     NaN  2026  Miami Grand Prix
# 765         AUD     6     NaN  2026  Miami Grand Prix
# 766          RB     6     NaN  2026  Miami Grand Prix
# 767         CAD     6     NaN  2026  Miami Grand Prix
#
#                    start_date       location country_code  meeting_key  month  \
# 763 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284      5
# 764 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284      5
# 765 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284      5
# 766 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284      5
# 767 2026-05-03 20:00:00+00:00  Miami Gardens          USA         1284      5
#
#      start_epoch
# 763   1777838400
# 764   1777838400
# 765   1777838400
# 766   1777838400
# 767   1777838400
#      driver  race constructor  year
# 1623    BOR     6         AUD  2026
# 1624    LIN     6          RB  2026
# 1625    COL     6         ALP  2026
# 1626    PER     6         CAD  2026
# 1627    BOT     6         CAD  2026

# %%
for df in dfs:
    print(df.shape)
# Out:
# (1724, 11)
# (1676, 11)
# (744, 11)
# (768, 11)
# (1488, 4)
